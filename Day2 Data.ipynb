# %%
import pandas as pd
import numpy as np

# %%
tips = pd.read_csv('data/tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.size
# Out:
# 1708

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
np.int

# %%
len(tips)
# Out:
# 244

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
type(tips['tip'])
# Out:
# pandas.core.series.Series

# %%
tips.tip + tips.total_bill    # vectorized operation
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %%
tips.tip + 10
# Out:
# 0      11.01
# 1      11.66
# 2      13.50
# 3      13.31
# 4      13.61
#        ...
# 239    15.92
# 240    12.00
# 241    12.00
# 242    11.75
# 243    13.00
# Name: tip, Length: 244, dtype: float64

# %%
tips.tip * 10
# Out:
# 0      10.1
# 1      16.6
# 2      35.0
# 3      33.1
# 4      36.1
#        ...
# 239    59.2
# 240    20.0
# 241    20.0
# 242    17.5
# 243    30.0
# Name: tip, Length: 244, dtype: float64

# %%
tips.tip > 5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
tips.size      # internal attribute
tips['size']   # column
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
len(tips[tips.tip > 5])
# Out:
# 18

# %%
tips[tips.tip > 5].tip
# Out:
# 23      7.58
# 44      5.60
# 47      6.00
# 52      5.20
# 59      6.73
# 85      5.17
# 88      5.85
# 116     5.07
# 141     6.70
# 155     5.14
# 170    10.00
# 172     5.15
# 181     5.65
# 183     6.50
# 211     5.16
# 212     9.00
# 214     6.50
# 239     5.92
# Name: tip, dtype: float64

# %%
# Find average tip paid by Females
tips[tips.sex == 'Female'].tip.mean()
# Out:
# np.float64(2.8334482758620685)

# %%
tips.tip.mean()
# Out:
# np.float64(2.99827868852459)

# %%
tips[tips.sex == 'Male'].tip.mean()
# Out:
# np.float64(3.0896178343949043)

# %%
(tips.sex == 'Male') & (tips.smoker == 'Yes')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241     True
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
tips.smoker == 'Yes'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240     True
# 241     True
# 242    False
# 243    False
# Name: smoker, Length: 244, dtype: bool

# %%
# Average tip paid by Male  Smokers
tips[(tips.sex == 'Male') & (tips.smoker == 'Yes')].tip.mean()
# Out:
# np.float64(3.051166666666667)

# %%
# Average tip by sex
tips.groupby('sex').tip.mean()
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %%
# Max total bill by sex and smoker
tips.groupby(['sex', 'smoker']).total_bill.max()
# Out:
# sex     smoker
# Female  No        35.83
#         Yes       44.30
# Male    No        48.33
#         Yes       50.81
# Name: total_bill, dtype: float64

# %%
Male Smoker: 
Male Non-smoker

# %%
# Count of Sunday dinners
len(tips[(tips.day == 'Sun') & (tips.time == 'Dinner')])
# Out:
# 76

# %%
((tips.day == 'Sun') & (tips.time == 'Dinner')).sum()
# Out:
# np.int64(76)

# %%
sum([1,2,3,4])
# Out:
# 10

# %%
sum([True, True, True, True])
# Out:
# 4

# %%
import seaborn as sns

# %%
mpg = sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
# Average mpg by origin
mpg.groupby('origin').mpg.mean()
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %%
# Average mpg by year and origin
mpg.groupby(['origin', 'model_year']).mpg.mean()
# Out:
# origin  model_year
# europe  70            25.200000
#         71            28.750000
#         72            22.000000
#         73            24.000000
#         74            27.000000
#         75            24.500000
#         76            24.250000
#         77            29.250000
#         78            24.950000
#         79            30.450000
#         80            37.288889
#         81            31.575000
#         82            40.000000
# japan   70            25.500000
#         71            29.500000
#         72            24.200000
#         73            20.000000
#         74            29.333333
#         75            27.500000
#         76            28.000000
#         77            27.416667
#         78            29.687500
#         79            32.950000
#         80            35.400000
#         81            32.958333
#         82            34.888889
# usa     70            15.272727
#         71            18.100000
# ...

# %%
# Average mpg by year and origin
mpg.groupby(['model_year', 'origin']).mpg.mean().unstack().plot()
# Out:
# <Axes: xlabel='model_year'>
